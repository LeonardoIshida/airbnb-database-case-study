# %% [markdown]
# ## Importando as bibliotecas e conectando na base de dados

# %%
from ipywidgets import interact 
import ipywidgets as widgets
from sqlalchemy import create_engine

# %%
# %load_ext sql

engine = create_engine('postgresql://postgres:pgadmin@localhost/airbnb_icmc')
# %sql postgresql://postgres:pgadmin@localhost/airbnb_icmc

# %% [markdown]
# ## Exercício 5

# %% [markdown]
# ### Mostrar a relação inteira

# %%
# %%sql
# SELECT *
# FROM Propriedade
# ORDER BY id ASC
# LIMIT 15;
# Out:
#  * postgresql://postgres:***@localhost/airbnb_icmc
# 15 rows affected.
# [(1, 'Apartamento Aconchegante', 'Rua das Flores', 123, 'Apt 101', 'São Paulo', 'São Paulo', 'Brasil', 'Centro', 'Patrícia', 'Gomes', '1135678901', 2, 'casal', 4, 2, 'apartamento', Decimal('200.00'), 4, 1, 7, Decimal('30.00'), datetime.time(14, 0), datetime.time(11, 0)),
#  (2, 'Casa na Praia', 'Av. Principal', 456, None, 'Rio de Janeiro', 'Rio de Janeiro', 'Brasil', 'Copacabana', 'Gustavo', 'Oliveira', '11987651234', 3, 'casal', 6, 2, 'casa própria', Decimal('300.00'), 6, 2, 14, Decimal('40.00'), datetime.time(15, 0), datetime.time(10, 0)),
#  (3, 'Chalé Charmoso', 'Rua dos Coqueiros', 789, 'Casa de Hóspedes', 'Belo Horizonte', 'Minas Gerais', 'Brasil', 'Centro', 'Camila', 'Lima', '1135678901', 1, 'solteiro', 2, 1, 'quarto individual', Decimal('100.00'), 2, 1, 7, Decimal('20.00'), datetime.time(16, 0), datetime.time(12, 0)),
# ...

# %% [markdown]
# ### Quantas propriedades existem de cada classe

# %%
# %%sql
# SELECT tipo_hospedagem, COUNT(*)
#     FROM Propriedade
#     GROUP BY tipo_hospedagem
# Out:
#  * postgresql://postgres:***@localhost/airbnb_icmc
# 4 rows affected.
# [('casa própria', 5),
#  ('quarto individual', 2),
#  ('chalé', 3),
#  ('apartamento', 5)]

# %% [markdown]
# ### Quantas propriedades existem de cada cidade

# %%
# %%sql
# SELECT L.cidade, COUNT(P.id)
#     FROM Propriedade P RIGHT OUTER JOIN
#         Localizacao L ON (P.cidade, P.estado, P.pais) = (L.cidade, L.estado, L.pais)
#     GROUP BY L.cidade
#     ORDER BY COUNT(P.id) DESC,
#              L.cidade ASC
#     LIMIT 15;
# Out:
#  * postgresql://postgres:***@localhost/airbnb_icmc
# 15 rows affected.
# [('Santos', 3),
#  ('Rio de Janeiro', 2),
#  ('São Paulo', 2),
#  ('Belo Horizonte', 1),
#  ('Campinas', 1),
#  ('Fortaleza', 1),
#  ('Los Angeles', 1),
#  ('Miami', 1),
#  ('Porto Alegre', 1),
#  ('Recife', 1),
#  ('São José dos Paraiabas', 1),
#  ('Boston', 0),
#  ('Brasília', 0),
#  ('Chicago', 0),
#  ('Curitiba', 0)]

# %% [markdown]
# ## Exercício 6

# %%
# %%sql
# SELECT
#      L.id as id_locacao,
#      P.id as id_prop,
#      R.nome_locatario as nome_loc, R.sobrenome_locatario as sobrenome_loc, R.num_tel_locatario as num_tel_loc,
#      data_check_out - data_check_in as dias_locados,
#      P.preco_noite as preco_diaria
# FROM
#      Reservar as R JOIN
#      Locacao as L ON (R.id_locacao = L.id) JOIN
#      Propriedade as P ON (R.id_prop = P.id)
# WHERE
#     R.confirmacao = TRUE and
#     L.data_check_in - '2024-04-01' > 0;
# Out:
#  * postgresql://postgres:***@localhost/airbnb_icmc
# 3 rows affected.
# [(1, 21, 'Lucas', 'Silva', '11987654321', 5, Decimal('100.00')),
#  (3, 25, 'Camila', 'Costa', '11987651234', 5, Decimal('500.00')),
#  (13, 27, 'Paula', 'Sousa', '1135678901', 1, Decimal('300.00'))]

# %% [markdown]
# ## Exercício 7

# %% [markdown]
# ## Exercício 8

# %%
# %%sql
# SELECT
#     P.nome_dono,
#     U.cidade,
#     numero_prop,
#     CB.num_conta,
#     COUNT(CB.num_conta) as quant_locacoes
# FROM
#     Reservar as R
#     JOIN
#         Propriedade as P
#         ON (R.id_prop = P.id)
#     JOIN (
#         SELECT
#             P.nome_dono,
#             P.sobrenome_dono,
#             P.num_tel_dono,
#             COUNT(*) as numero_prop
#         FROM
#             Propriedade as P
#         GROUP BY
#             P.nome_dono,
#             P.sobrenome_dono,
#             P.num_tel_dono
#     ) as quant_propriedades
#         Using (nome_dono, sobrenome_dono, num_tel_dono)
#     JOIN
#         Usuario as U
#         ON (P.nome_dono, P.sobrenome_dono, P.num_tel_dono) =
#             (U.nome, U.sobrenome, U.num_tel)
#     JOIN
#         Conta_bancaria as CB
#             ON (P.nome_dono, P.sobrenome_dono, P.num_tel_dono) =
#                 (CB.nome_dono, CB.sobrenome_dono, CB.num_tel_dono)
# GROUP BY
#     P.nome_dono,
#     numero_prop,
#     U.cidade,
#     CB.num_conta
# HAVING
#     COUNT(CB.num_conta) >= 3;
# Out:
#  * postgresql://postgres:***@localhost/airbnb_icmc
# 2 rows affected.
# [('Marcos', 'Belo Horizonte', 2, '987654321', 3),
#  ('Rodrigo', 'São José dos Campos', 3, '888888888', 3)]

# %% [markdown]
# ## Exercício 9

# %%
# %%sql
# SELECT *
# FROM
#     Usuario
# WHERE
#     tipo = 'locatário e proprietário'
# Out:
#  * postgresql://postgres:***@localhost/airbnb_icmc
# 3 rows affected.
# [('Marcos', 'Oliveira', '1135678901', 'locatário e proprietário', 'Rua dos Coqueiros', 789, 'Bloco B', 'Belo Horizonte', 'Minas Gerais', 'Brasil', 'Centro', datetime.date(1980, 3, 25), 'M', 'marcos.oliveira@example.com', 'senha789'),
#  ('Rodrigo', 'Machado', '11987651234', 'locatário e proprietário', 'Rua das Orquídeas', 666, None, 'São José dos Campos', 'São Paulo', 'Brasil', 'Vila Ema', datetime.date(1983, 1, 30), 'M', 'rodrigo.machado@example.com', 'senha6666'),
#  ('Gustavo', 'Oliveira', '11987651234', 'locatário e proprietário', 'Rua das Orquídeas', 666, None, 'São José dos Campos', 'São Paulo', 'Brasil', 'Vila Ema', datetime.date(1983, 1, 30), 'M', 'gustavo.oliveira@example.com', 'senha1111')]

# %% [markdown]
# ## Exercício 10
